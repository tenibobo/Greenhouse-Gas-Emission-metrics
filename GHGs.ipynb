# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Methane emissions_sourcesYear2015.csv',index_col= 0,parse_dates = True)

# %%
df = df.groupby('ipcc_code_2006_for_standard_report_name').sum()
df
df.to_excel(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_CH4_m_2000_2021\PythonRemake\Sources2000.xlsx', sheet_name='GlobalSourcesYear2000', index= True)

# %%
df2 = pd.read_csv('Methane emissions_sourcesYear2021.csv',index_col= 0,parse_dates = True)

# %%
df2= df2.groupby('ipcc_code_2006_for_standard_report_name').sum().drop(['Year'], axis=1)
df2
# Out:
#                                                             Total
# ipcc_code_2006_for_standard_report_name
# Biological Treatment of Solid Waste                    287.767465
# Chemical Industry                                      360.161416
# Civil Aviation                                           4.866640
# Emissions from biomass burning                        1982.631127
# Enteric Fermentation                                112762.101807
# Fossil fuel fires                                      150.600004
# Incineration and Open Burning of Waste                1570.728240
# Main Activity Electricity and Heat Production          477.313600
# Manufacturing Industries and Construction              667.308985
# Manure Management                                    12710.630824
# Metal Industry                                         154.772639
# Non-Specified                                          320.233566
# Oil and Natural Gas                                  72814.172433
# ...

# %%
df2.to_excel(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_CH4_m_2000_2021\PythonRemake\Sources2015.xlsx', sheet_name='GlobalSourcesYear2015', index= True)

# %%
df3 = pd.read_csv('Methane emissions_sourcesYear2000.csv',index_col= 0, parse_dates = True)

# %%
df3=df3.groupby('ipcc_code_2006_for_standard_report_name').sum(['Total']).drop(['Year'], axis=1)
df3
# Out:
#                                                            Total
# ipcc_code_2006_for_standard_report_name
# Biological Treatment of Solid Waste                   171.615888
# Chemical Industry                                     131.166727
# Civil Aviation                                          4.721283
# Emissions from biomass burning                       1345.070315
# Enteric Fermentation                                91701.326135
# Fossil fuel fires                                     150.600004
# Incineration and Open Burning of Waste               1136.473478
# Main Activity Electricity and Heat Production         207.896729
# Manufacturing Industries and Construction             436.033293
# Manure Management                                   10871.203204
# Metal Industry                                         61.364937
# Non-Specified                                         288.706028
# Oil and Natural Gas                                 63784.315285
# ...

# %%
df3.to_excel(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_CH4_m_2000_2021\PythonRemake\Sources2021.xlsx', sheet_name='GlobalSourcesYear2021', index= True)

# %%
df4 = pd.read_csv('Methane emissions_sourcesGlobalAll.csv',index_col= 0, parse_dates = True)
df4
# Out:
#           Name fossil_bio            ipcc_code_2006_for_standard_report_name  \
# id
# 88707   Zambia     fossil                 Wastewater Treatment and Discharge
# 88708   Zambia     fossil  Petroleum Refining - Manufacture of Solid Fuel...
# 88709   Zambia     fossil                               Enteric Fermentation
# 88710   Zambia     fossil                                  Rice cultivations
# 88711   Zambia     fossil                                  Manure Management
# ...        ...        ...                                                ...
# 37597  Hungary     fossil                               Solid Waste Disposal
# 37598  Hungary     fossil                 Wastewater Treatment and Discharge
# 37599  Hungary     fossil                               Enteric Fermentation
# 37600  Hungary     fossil                                  Manure Management
# 37601  Hungary     fossil                                      Non-Specified
#
#        Year       Total
# id
# ...

# %%
df4 = df4.groupby(['Year', 'Name']).sum(['Total'])
df4
# Out:
#                                    Total
# Year Name
# 2000 Afghanistan              406.596134
#      Albania                  106.507736
#      Algeria                 3172.889008
#      Angola                  1736.191529
#      Anguilla                   0.115465
# ...                                  ...
# 2021 Virgin Islands_British     0.304879
#      Western Sahara             7.713922
#      Yemen                    506.685945
#      Zambia                   448.560499
#      Zimbabwe                 538.984900
#
# [4620 rows x 1 columns]

# %%
df4.to_excel(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_CH4_m_2000_2021\PythonRemake\Methane emissions_GlobalYear.xlsx', sheet_name='GlobalYear', index= True)

# %%
plt.figure(figsize=(12,9))
plt.title('Annual Global Methane Emission')
fig = sns.barplot(x = df4.index, y= 'Total', data = df4)
plt.savefig(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_CH4_m_2000_2021\PythonRemake\GlobalMethaneANnual.png', dpi=500, format='png')

# %%
plt.savefig(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_CH4_m_2000_2021\PythonRemake\GlobalMethaneANnual.png', dpi=500, format='png')

# %%
df5 = pd.read_csv('Methane emissions_sourcesGlobal.csv',index_col= 0, parse_dates = True)
df5
# Out:
#          fossil_bio            ipcc_code_2006_for_standard_report_name  Year  \
# Name
# Aruba           bio                                        Solid Fuels  2000
# Aruba           bio      Main Activity Electricity and Heat Production  2000
# Aruba           bio                                      Non-Specified  2000
# Aruba           bio          Manufacturing Industries and Construction  2000
# Aruba           bio                      Residential and other sectors  2000
# ...             ...                                                ...   ...
# Zimbabwe     fossil          Manufacturing Industries and Construction  2021
# Zimbabwe     fossil                                     Metal Industry  2021
# Zimbabwe     fossil  Petroleum Refining - Manufacture of Solid Fuel...  2021
# Zimbabwe     fossil      Main Activity Electricity and Heat Production  2021
# Zimbabwe     fossil                               Solid Waste Disposal  2021
#
#               Total
# Name
# ...

# %%
df5 = df5.groupby(['Year', 'ipcc_code_2006_for_standard_report_name']).sum(['Total'])
df5
# Out:
#                                                      Total
# Year ipcc_code_2006_for_standard_report_name
# 2000 Biological Treatment of Solid Waste        171.615888
#      Chemical Industry                          131.166727
#      Civil Aviation                               4.721283
#      Emissions from biomass burning            1345.070315
#      Enteric Fermentation                     91701.326137
# ...                                                    ...
# 2021 Road Transportation no resuspension        951.522702
#      Solid Fuels                              51141.083738
#      Solid Waste Disposal                     36178.641569
#      Wastewater Treatment and Discharge       46885.487474
#      Water-borne Navigation                      80.584618
#
# [506 rows x 1 columns]

# %%
df5.to_excel(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_CH4_m_2000_2021\PythonRemake\Methane emissions_SourcesYear.xlsx', sheet_name='SourcesYear', index= True)

# %%
df6 = pd.read_csv ('CO2_EmissionGLobalAnnual.csv', index_col = 0, parse_dates = True)
df6
# Out:
#                  ipcc_code_2006_for_standard_report_name  Year  Total_Emission
# Name
# Aruba                                      Non-Specified  2000        0.676061
# Aruba      Main Activity Electricity and Heat Production  2000        1.073614
# Aruba          Manufacturing Industries and Construction  2000        4.501023
# Aruba                      Residential and other sectors  2000        1.394168
# Aruba                             Water-borne Navigation  2000        2.470643
# ...                                                  ...   ...             ...
# Zimbabwe                                Glass Production  2021        0.839446
# Zimbabwe  Non-Energy Products from Fuels and Solvent Use  2021       57.980657
# Zimbabwe             Road Transportation no resuspension  2021     2239.569449
# Zimbabwe                   Residential and other sectors  2021      540.585112
# Zimbabwe                Other Process Uses of Carbonates  2021        1.417387
#
# ...

# %%
df6 = df6.groupby(['Year', 'ipcc_code_2006_for_standard_report_name']).sum(['Total'])
df6
# Out:
#                                               Total_Emission
# Year ipcc_code_2006_for_standard_report_name
# 2000 Cement production                          7.310938e+05
#      Chemical Industry                          4.268283e+05
#      Civil Aviation                             6.749793e+05
#      Emissions from biomass burning             7.547339e+05
#      Fossil fuel fires                          4.748920e+04
# ...                                                      ...
# 2021 Residential and other sectors              6.324480e+06
#      Road Transportation no resuspension        6.081655e+06
#      Solid Fuels                                5.217692e+05
#      Urea application                           8.168080e+04
#      Water-borne Navigation                     8.779705e+05
#
# [528 rows x 1 columns]

# %%
df6.to_excel(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_CO2_m_2000_2021\Python Remake\CO2SourcesYear.xlsx',
             sheet_name= 'CO2SourcesYear', index= True)

# %%
df7 = pd.read_csv('N2O_EmissionGlobalAnnual.csv',index_col= 0, parse_dates = True)
df7
# Out:
#           Year Substance  Total_Emission
# Name
# Aruba     2000       N2O        0.058396
# Aruba     2001       N2O        0.059848
# Aruba     2002       N2O        0.056792
# Aruba     2003       N2O        0.069728
# Aruba     2004       N2O        0.075462
# ...        ...       ...             ...
# Zimbabwe  2017       N2O       16.343557
# Zimbabwe  2018       N2O       16.531769
# Zimbabwe  2019       N2O       16.681290
# Zimbabwe  2020       N2O       17.048230
# Zimbabwe  2021       N2O       17.677363
#
# [4620 rows x 3 columns]

# %%
df7=df7.groupby(['Year', 'Name']).sum(['Total'])
df7
# Out:
#                              Total_Emission
# Year Name
# 2000 Afghanistan                   9.156054
#      Albania                       3.370727
#      Algeria                      14.092249
#      Angola                       10.233393
#      Anguilla                      0.001442
# ...                                     ...
# 2021 Virgin Islands_British        0.020031
#      Western Sahara                0.043641
#      Yemen                        13.389047
#      Zambia                       26.284465
#      Zimbabwe                     17.677363
#
# [4620 rows x 1 columns]

# %%
df7.to_excel(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_N2O_m_2000_2021\Python Remake\N20GlobalYear.xlsx',
             sheet_name= 'N20GlobalYear', index= True)

# %%
df8 = pd.read_csv('CO2Netherlands.csv', index_col= 0, parse_dates = True)
df8
# Out:
#                    ipcc_code_2006_for_standard_report_name fossil_bio  \
# Name
# Netherlands                 Emissions from biomass burning        bio
# Netherlands      Manufacturing Industries and Construction        bio
# Netherlands  Main Activity Electricity and Heat Production        bio
# Netherlands                  Residential and other sectors        bio
# Netherlands         Incineration and Open Burning of Waste        bio
# ...                                                    ...        ...
# Netherlands      Manufacturing Industries and Construction     fossil
# Netherlands                                       Railways     fossil
# Netherlands                         Water-borne Navigation     fossil
# Netherlands                                         Liming     fossil
# Netherlands                                 Metal Industry     fossil
#
#             Substance  Year         Total
# Name
# Netherlands       CO2  2000    137.595855
# ...

# %%
df8 = df8.groupby(['Year', 'ipcc_code_2006_for_standard_report_name']).sum(['Total'])
df8
# Out:
#                                                      Total
# Year ipcc_code_2006_for_standard_report_name
# 2000 Cement production                          451.949998
#      Chemical Industry                        10740.344440
#      Civil Aviation                              55.357502
#      Emissions from biomass burning             137.595855
#      Glass Production                           214.200000
# ...                                                    ...
# 2021 Residential and other sectors            31039.491746
#      Road Transportation no resuspension      28661.871460
#      Solid Fuels                                489.768842
#      Urea application                             4.714285
#      Water-borne Navigation                     785.170444
#
# [460 rows x 1 columns]

# %%
df8.to_excel(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_CO2_m_2000_2021\Python Remake\NetherlandsCO2SourcesYear.xlsx',
             sheet_name= 'NetherlandsCO2SourcesYear', index= True)

# %%
df9 = pd.read_csv('NetherlandsCO2SourcesYear.csv', index_col = 0, parse_dates = True)
df9
# Out:
#                                         2000          2001          2002  \
# Sources
# Cement production                 451.949998    459.679998    472.769998
# Chemical Industry               10740.344440  10243.736050  10449.748950
# Civil Aviation                     55.357502     52.283002     46.134001
# Emissions from biomass burning    137.595855    126.889396    129.364018
# Glass Production                  214.200000    215.880000    198.240000
# ...                                      ...           ...           ...
# NaN                                      NaN           NaN           NaN
# NaN                                      NaN           NaN           NaN
# NaN                                      NaN           NaN           NaN
# NaN                                      NaN           NaN           NaN
# NaN                                      NaN           NaN           NaN
#
#                                        2003          2004         2005  \
# ...

# %%
newdf9 = df9.T
newdf9
# Out:
# Sources  Cement production  Chemical Industry  Civil Aviation  \
# 2000            451.949998       10740.344440       55.357502
# 2001            459.679998       10243.736050       52.283002
# 2002            472.769998       10449.748950       46.134001
# 2003            418.949998        9840.504583       52.283002
# 2004            428.399998       10380.767190       43.059501
# 2005            424.999998        9869.778492       43.054001
# 2006            407.339998        9809.943770       36.905001
# 2007            440.099998        9958.413999       39.979501
# 2008            430.899998       10158.486690       39.979501
# 2009            416.519998       10418.210020       36.905001
# 2010            365.597998       10636.266700       39.979501
# 2011            350.017998       10857.990040       43.054001
# 2012            316.219999        9987.687287       43.054001
# 2013            286.999999        9463.711971       36.899501
# ...

# %%
newdf9.to_excel(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_CO2_m_2000_2021\Python Remake\transposeNetherlandsCO2SourcesYear.xlsx',
             sheet_name= 'NetherlandsCO2SourcesYear', index= True)

# %%
##EXPLORATORY DATA ANALYSIS (EDA)

# %%
df10 = pd.read_csv('transposeNetherlandsCO2SourcesYear.csv', index_col = 0, parse_dates = True)
df10
# Out:
#             Cement production  Chemical Industry  Civil Aviation  \
# 2000-01-01         451.949998       10740.344440       55.357502
# 2001-01-01         459.679998       10243.736050       52.283002
# 2002-01-01         472.769998       10449.748950       46.134001
# 2003-01-01         418.949998        9840.504583       52.283002
# 2004-01-01         428.399998       10380.767190       43.059501
# 2005-01-01         424.999998        9869.778492       43.054001
# 2006-01-01         407.339998        9809.943770       36.905001
# 2007-01-01         440.099998        9958.413999       39.979501
# 2008-01-01         430.899998       10158.486690       39.979501
# 2009-01-01         416.519998       10418.210020       36.905001
# 2010-01-01         365.597998       10636.266700       39.979501
# 2011-01-01         350.017998       10857.990040       43.054001
# 2012-01-01         316.219999        9987.687287       43.054001
# ...

# %%
df10.info()
df10.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 22 entries, 2000-01-01 to 2021-01-01
# Data columns (total 22 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Cement production                                                            20 non-null     float64
#  1   Chemical Industry                                                            22 non-null     float64
#  2   Civil Aviation                                                               22 non-null     float64
#  3   Emissions from biomass burning                                               22 non-null     float64
#  4   Glass Production                                                             22 non-null     float64
#  5   Incineration and Open Burning of Waste                                       22 non-null     float64
# ...

# %%
df10.duplicated().sum()
# Out:
# 0

# %%
df10['Chemical Industry'].unique()
# Out:
# array([10740.34444 , 10243.73605 , 10449.74895 ,  9840.504583,
#        10380.76719 ,  9869.778492,  9809.94377 ,  9958.413999,
#        10158.48669 , 10418.21002 , 10636.2667  , 10857.99004 ,
#         9987.687287,  9463.711971,  9306.280716,  9047.656425,
#         9529.538161,  9899.936901,  9271.577804,  9220.111621,
#         8702.023099,  8438.059131])

# %%
sns.countplot(df10['Chemical Industry']).unique()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11756\3766872759.py in <module>
# ----> 1 sns.countplot(df10['Chemical Industry']).unique()
#
# AttributeError: 'AxesSubplot' object has no attribute 'unique'

# %%
df10.isna().sum()
# Out:
# Cement production                                                              2
# Chemical Industry                                                              0
# Civil Aviation                                                                 0
# Emissions from biomass burning                                                 0
# Glass Production                                                               0
# Incineration and Open Burning of Waste                                         0
# Liming                                                                         0
# Main Activity Electricity and Heat Production                                  0
# Manufacturing Industries and Construction                                      0
# Metal Industry                                                                 0
# Non-Energy Products from Fuels and Solvent Use                                 0
# Non-Specified                                                                  0
# ...

# %%
df10.replace(np.nan, '0', inplace= True)

# %%
df10.dtypes
# Out:
# Cement production                                                               object
# Chemical Industry                                                              float64
# Civil Aviation                                                                 float64
# Emissions from biomass burning                                                 float64
# Glass Production                                                               float64
# Incineration and Open Burning of Waste                                         float64
# Liming                                                                         float64
# Main Activity Electricity and Heat Production                                  float64
# Manufacturing Industries and Construction                                      float64
# Metal Industry                                                                 float64
# Non-Energy Products from Fuels and Solvent Use                                 float64
# ...

# %%
df10['Cement production'] = df10['Cement production'].astype('float64')

# %%
df10.dtypes
# Out:
# Cement production                                                              float64
# Chemical Industry                                                              float64
# Civil Aviation                                                                 float64
# Emissions from biomass burning                                                 float64
# Glass Production                                                               float64
# Incineration and Open Burning of Waste                                         float64
# Liming                                                                         float64
# Main Activity Electricity and Heat Production                                  float64
# Manufacturing Industries and Construction                                      float64
# Metal Industry                                                                 float64
# Non-Energy Products from Fuels and Solvent Use                                 float64
# ...

# %%
df10[['Water-borne Navigation']].boxplot()
# Out:
# <AxesSubplot:>

# %%
df10.corr()
# Out:
#                                                     Cement production  \
# Cement production                                            1.000000
# Chemical Industry                                            0.805789
# Civil Aviation                                               0.828762
# Emissions from biomass burning                               0.440486
# Glass Production                                             0.883110
# Incineration and Open Burning of Waste                       0.827792
# Liming                                                       0.870948
# Main Activity Electricity and Heat Production                0.722285
# Manufacturing Industries and Construction                    0.323174
# Metal Industry                                               0.641699
# Non-Energy Products from Fuels and Solvent Use               0.332897
# Non-Specified                                                0.575526
# ...

# %%
sns.heatmap(df10.corr())
# Out:
# <AxesSubplot:>

# %%
plt.savefig(r'C:\Users\User\OneDrive\Documents\My Tableau Repository\Datasources\Monthly Emissions data\v70_FT2021_CO2_m_2000_2021\Python Remake\NetherlandsCO2.png', dpi=500, format='png')
plt.show()
